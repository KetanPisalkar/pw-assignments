# %% [markdown]
# <a href="https://colab.research.google.com/github/KetanPisalkar/pw-assignments/blob/python/OperatorAssignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Que1.calculate sum,difference,product and quotient of two number?

# %%
a=1
b=2
a+b
# Out:
# 3

# %%
a-b
# Out:
# -1

# %%
a*b
# Out:
# 2

# %%
a/b
# Out:
# 0.5

# %% [markdown]
# que2.perform various assignmet operations on avariables?

# %%
x=2

# %%
y=x

# %%
x+=y

# %%
x
# Out:
# 4

# %%
x-=y

# %%
x
# Out:
# 2

# %%
x*=y

# %%
x
# Out:
# 4

# %%
x/=y

# %%
x
# Out:
# 2.0

# %%
x%=y

# %%
x
# Out:
# 0.0

# %% [markdown]
#  que3.Compare two number and print the result?

# %%
a=int(input("enter first number"))
b=int(input("enter secind number"))
if a==b:
  print("both the numbe are equal")
else:
  print("both arer not equal")
# Out:
# enter first number2
# enter secind number2
# both the numbe are equal

# %% [markdown]
# Que4.check condition using logical operator?

# %%
u=int(input("etner a number 1 or 0"))
v=int(input("enter another number 1 or 0"))
if v==1 and u==1:
  print("True")
else:
  print("false")
# Out:
# etner a number 1 or 01
# enter another number 1 or 00
# false

# %% [markdown]
#  Que5.Check the identity of variable?

# %%
x='ketan'
print(id(x))
# Out:
# 134688196342000

# %%
c=2
print(id(c))
# Out:
# 134689477198096

# %%
r=2.3
print(id(r))
# Out:
# 134688199752496

# %%
v-True
print(id(v))
# Out:
# 134689477198032

# %%
list=['hello',2,2.3,False]
print(id(list))
# Out:
# 134688195100736

# %% [markdown]
# Que6.perform Bitwise operation with two integers?

# %%
g=1
j=2

# %%
print(g and j)
# Out:
# 2

# %%
print(g | j)
# Out:
# 3

# %%
print(~g)
# Out:
# -2

# %%
print(g^j)
# Out:
# 3

# %% [markdown]
# Que7.Use unary operation to change the sign of the number?

# %%
j=4
u=-j
print(u)
# Out:
# -4

# %%
r=-4
g=-r
print(g)
# Out:
# 4

# %% [markdown]
# Que8. use the ternary operator to assign value based on condition

# %%
o=int(input("enter first number"))
d=int(input("enter secind"))
max_value= o if o>d else d
print(max_value)
# Out:
# enter first number23
# enter secind21
# 23
