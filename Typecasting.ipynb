# %% [markdown]
# <a href="https://colab.research.google.com/github/KetanPisalkar/pw-assignments/blob/python/Typecasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Que1.converting integer to an floating-point  number?

# %%
a=3
type(a)
# Out:
# int

# %%
b=float(a)
type(b)
# Out:
# float

# %%
b
# Out:
# 3.0

# %% [markdown]
# que2.convert a float into a integer?

# %%
n=2.0
type(n)
# Out:
# float

# %%
d=int(n)
type(d)
# Out:
# int

# %%
d
# Out:
# 2

# %% [markdown]
# Que3.convert an integer to an string?

# %%
c=2
type(c)
# Out:
# int

# %%
k=str(c)
type(k)
# Out:
# str

# %%
k
# Out:
# '2'

# %% [markdown]
# Que4.convert a list to a tupple?

# %%
x=['hello',2.2,2,True]
type(x)
# Out:
# list

# %%
o=tuple(x)
type(o)
# Out:
# tuple

# %%
o
# Out:
# ('hello', 2.2, 2, True)

# %% [markdown]
# Que5.convert a tuple to a last?

# %%
y=('bye',2,2.2,False)
type(y)
# Out:
# tuple

# %%
h=list[y]
type(h)
# Out:
# types.GenericAlias

# %%
h
# Out:
# list[list['bye', 2, 2.2, False]]

# %% [markdown]
# Que6.convert non zero number to boolean?

# %%
q=1

# %%
v=bool(q)
v
# Out:
# True
